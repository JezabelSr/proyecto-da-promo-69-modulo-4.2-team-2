# %%
import pandas as pd
import os

RUTA = r'C:\Users\jezab\OneDrive\Escritorio\Adalab\Proyectos\proyectos_grupales\proyecto-da-promo-69-modulo-4.2-team-2'

df = pd.read_csv(os.path.join(RUTA, 'df_main.csv'))

print(df['averageRating'].describe())
print(df['averageRating'].head(10))
# Out:
# count    38531.000000
# mean         5.255477
# std          1.408751
# min          1.000000
# 25%          4.300000
# 50%          5.300000
# 75%          6.300000
# max          9.900000
# Name: averageRating, dtype: float64
# 0    6.4
# 1    6.8
# 2    3.7
# 3    5.6
# 4    3.8
# 5    4.9
# 6    3.1
# 7    3.6
# 8    3.6
# 9    4.9
# Name: averageRating, dtype: float64

# %%
df = pd.read_csv(os.path.join(RUTA, 'df_main.csv'))

df_generos = df[['tconst', 'genres']].copy()
df_generos['genres'] = df_generos['genres'].str.split(',')
df_generos = df_generos.explode('genres')
df_generos['genres'] = df_generos['genres'].str.strip()
df_generos = df_generos.dropna()

print(df_generos.shape)
print(df_generos['genres'].value_counts())
print(df_generos.head(10))
# Out:
# (95414, 2)
# genres
# Acción             16197
# Terror             13839
# Drama              12461
# Comedy              9382
# Adventure           8079
# Thriller            7637
# Crime               5132
# Fantasía            4960
# Ciencia Ficción     4208
# Animación           3374
# Mystery             3356
# Family              2259
# Romance             1772
# History              587
# Documentary          541
# Biography            463
# War                  346
# Musical              259
# Sport                228
# Music                191
# Western              137
# News                   4
# Reality-TV             2
# Name: count, dtype: int64
#       tconst     genres
# 0  tt0035423     Comedy
# 0  tt0035423   Fantasía
# 0  tt0035423    Romance
# 1  tt0066020     Acción
# 1  tt0066020     Comedy
# 2  tt0066151     Acción
# 2  tt0066151  Adventure
# 3  tt0067100     Acción
# 3  tt0067100      Drama
# 3  tt0067100   Thriller

# %%
df_generos.to_csv(os.path.join(RUTA, 'df_generos.csv'), index=False)
print("Guardado!")
# Out:
# Guardado!

# %%
generos_frikis = ["Action", "Horror", "Sci-Fi", "Animation", "Fantasy"]

mask = df['genres'].apply(lambda x: any(g in str(x) for g in generos_frikis))
print(df[mask].shape[0])
# Out:
# 0

# %%
print(df['production_countries'].isnull().sum())
print(df.shape[0])
# Out:
# 36555
# 38531

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38531 entries, 0 to 38530
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   tconst                38531 non-null  str
#  1   primaryTitle          38531 non-null  str
#  2   originalTitle         38531 non-null  str
#  3   startYear             38531 non-null  int64
#  4   runtimeMinutes        37994 non-null  float64
#  5   genres                38531 non-null  str
#  6   averageRating         38531 non-null  float64
#  7   numVotes              38531 non-null  float64
#  8   director_name         38459 non-null  str
#  9   imdb_url              7729 non-null   str
#  10  budget                1722 non-null   float64
#  11  revenue               1570 non-null   float64
#  12  production_countries  1976 non-null   str
#  13  production_companies  1976 non-null   str
#  14  popularity            5802 non-null   float64
#  15  worldwide             2526 non-null   float64
#  16  domestic              2526 non-null   float64
#  17  foreign               2526 non-null   float64
#  18  overview              5227 non-null   str
# dtypes: float64(9), int64(1), str(9)
# memory usage: 5.6 MB
